# %% [markdown]
# # **Real Estate price Prediction**

# %% [markdown]
# ## **Load Data**

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/rayquaza/Desktop/Real estate price prediction/dataset/Real estate.csv',index_col=0)
df
# Out:
#      X1 transaction date  X2 house age  \
# No
# 1               2012.917          32.0
# 2               2012.917          19.5
# 3               2013.583          13.3
# 4               2013.500          13.3
# 5               2012.833           5.0
# ..                   ...           ...
# 410             2013.000          13.7
# 411             2012.667           5.6
# 412             2013.250          18.8
# 413             2013.000           8.1
# 414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 1                                  84.87882                               10
# 2                                 306.59470                                9
# 3                                 561.98450                                5
# 4                                 561.98450                                5
# 5                                 390.56840                                5
# ...

# %%
df.count()
# Out:
# X1 transaction date                       414
# X2 house age                              414
# X3 distance to the nearest MRT station    414
# X4 number of convenience stores           414
# X5 latitude                               414
# X6 longitude                              414
# Y house price of unit area                414
# dtype: int64

# %%
df.columns
# Out:
# Index(['X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ## **Data cleanning**

# %% [markdown]
# ### Sepration of x and y

# %%
y=df['Y house price of unit area']
y
# Out:
# No
# 1      37.9
# 2      42.2
# 3      47.3
# 4      54.8
# 5      43.1
#        ...
# 410    15.4
# 411    50.0
# 412    40.6
# 413    52.5
# 414    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
x=df.drop('Y house price of unit area',axis=1)
x
# Out:
#      X1 transaction date  X2 house age  \
# No
# 1               2012.917          32.0
# 2               2012.917          19.5
# 3               2013.583          13.3
# 4               2013.500          13.3
# 5               2012.833           5.0
# ..                   ...           ...
# 410             2013.000          13.7
# 411             2012.667           5.6
# 412             2013.250          18.8
# 413             2013.000           8.1
# 414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 1                                  84.87882                               10
# 2                                 306.59470                                9
# 3                                 561.98450                                5
# 4                                 561.98450                                5
# 5                                 390.56840                                5
# ...

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=100)

# %%
x_train
# Out:
#      X1 transaction date  X2 house age  \
# No
# 273             2012.750          13.0
# 391             2013.500          32.8
# 70              2012.833          12.5
# 326             2013.083          36.6
# 200             2013.417          18.2
# ..                   ...           ...
# 344             2013.000          33.5
# 360             2013.500           5.6
# 324             2013.417          28.6
# 281             2013.250           2.3
# 9               2013.500          31.7
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 273                                492.2313                                5
# 391                                377.8302                                9
# 70                                 561.9845                                5
# 326                                488.8193                                8
# 200                                451.6419                                8
# ...

# %%
x_test
# Out:
#      X1 transaction date  X2 house age  \
# No
# 122             2013.500          13.6
# 354             2013.500           4.1
# 97              2013.417           6.4
# 44              2012.750          34.4
# 126             2013.167           1.1
# ..                   ...           ...
# 158             2013.250          16.1
# 185             2012.750          14.1
# 130             2013.417          38.5
# 358             2013.417           0.0
# 242             2013.500          13.7
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 122                               492.23130                                5
# 354                              2147.37600                                3
# 97                                 90.45606                                9
# 44                                512.78710                                6
# 126                               193.58450                                6
# ...

# %% [markdown]
# ## **Model building**

# %% [markdown]
# ### Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Applying the model

# %%
y_lr_pred_train=lr.predict(x_train)
y_lr_pred_test=lr.predict(x_test)

# %% [markdown]
# ### Evaluate the model

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_lr_pred_test_mse=mean_squared_error(y_test,y_lr_pred_test)
y_lr_pred_train_mse=mean_squared_error(y_train,y_lr_pred_train)


y_lr_pred_test_r2=r2_score(y_test,y_lr_pred_test)
y_lr_pred_train_r2=r2_score(y_train,y_lr_pred_train)

# %%
results_lr=pd.DataFrame(['Ljnear Regression',y_lr_pred_test_mse,y_lr_pred_train_mse,y_lr_pred_test_r2,y_lr_pred_train_r2]).transpose()
results_lr.columns=['Model','Test MSE','Train MSE','Test R2','Train R2']
results_lr
# Out:
#                Model   Test MSE  Train MSE   Test R2  Train R2
# 0  Ljnear Regression  49.381833  84.264202  0.669199  0.562874

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Applying the model

# %%
y_rf_pred_train=lr.predict(x_train)
y_rf_pred_test=lr.predict(x_test)

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn.metrics import mean_squared_error ,r2_score

# %%
y_rf_pred_test_mse=mean_squared_error(y_test,y_rf_pred_test)
y_rf_pred_train_mse=mean_squared_error(y_train,y_rf_pred_train)


y_rf_pred_test_r2=r2_score(y_test,y_rf_pred_test)
y_rf_pred_train_r2=r2_score(y_train,y_rf_pred_train)

# %%
results_rf=pd.DataFrame(['Ljnear Regression',y_rf_pred_test_mse,y_rf_pred_train_mse,y_rf_pred_test_r2,y_rf_pred_train_r2]).transpose()
results_rf.columns=['Model','Test MSE','Train MSE','Test R2','Train R2']
results_rf
# Out:
#                Model   Test MSE  Train MSE   Test R2  Train R2
# 0  Ljnear Regression  49.381833  84.264202  0.669199  0.562874

# %% [markdown]
# # **Data Visualization of prediction**

# %% [markdown]
# ## concatination

# %%
results=pd.concat([results_lr,results_rf])
results
# Out:
#                Model   Test MSE  Train MSE   Test R2  Train R2
# 0  Ljnear Regression  49.381833  84.264202  0.669199  0.562874
# 0  Ljnear Regression  49.381833  84.264202  0.669199  0.562874

# %% [markdown]
# ### Data Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Linear Regression

# %%
plt.scatter(x=y_test,y=y_lr_pred_test,alpha=0.3)
plt.xlabel('Experimental Values')
plt.ylabel('Predicted Values')
z=np.polyfit(y_train,y_lr_pred_train,1)
p=np.poly1d(z)
plt.plot(y_train,p(y_train),'Red')

# %% [markdown]
# #### Random Forest

# %%
plt.scatter(x=y_test,y=y_rf_pred_test,alpha=0.3)
plt.xlabel('Experimental Values')
plt.ylabel('Predicted Values')
z=np.polyfit(y_train,y_rf_pred_train,1)
p=np.poly1d(z)
plt.plot(y_train,p(y_train),'Red')
